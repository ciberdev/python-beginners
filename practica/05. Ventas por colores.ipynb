# %% [markdown]
# Hay una gran pila de calcetines que deben emparejarse por color. Dada una serie de números enteros que representan el color de cada calcetín, determine cuántos pares de calcetines con colores iguales hay.
#
# Ejemplo
# n=7
# ar = [1,2,1,2,1,3,2]
#
#
# Hay un par de color 1 y otro de color 2. Quedan tres calcetines impares, uno de cada color. El numero de parejas es 2.
#
# <br><b>Descripción de la función</b><br>
#
# Complete la función buscaPares en el editor a continuación.
#
# buscaPares tiene los siguientes parámetros:
# <ul>
# <li>int n: el número de calcetines en la pila</li>
# <li>int ar[n]: los colores de cada calcetín</li>
# </ul>
#
# <br><b>Retorna</b><br>
# <ul>
# <li>int: el número de pares</li>
# </ul>
#
# <br><b>Formato de entrada</b><br>
# La primera línea contiene un número entero n, el número de calcetines representados en ar.
# La segunda línea contieneenteros separados por espacios,, los colores de los calcetines en el montón.
#
# <br><b>Restricciones</b><br>
# <ul>
# <li>1 <= n <= 100</li>
# <li>1 <= ar[i] <= 100 dónde 0 <= i < n</li>
# </ul>
#
# <br><b>Ejemplo</b><br>
#
# <table width="500" style="float:left">
#     <tr>
#         <td width="50%">STDIN</td><td>Function</td>
#    </tr>
#    <tr>
#         <td>-----</td><td>--------</td>
#
#    </tr>
#    <tr>
#         <td>9</td><td>n = 9</td>
#
#    </tr>
#    <tr>
#         <td>10 20 20 10 10 30 50 10 20</td><td>ar = [10, 20, 20, 10, 10, 30, 50, 10, 20]</td>
#    <tr>
# <table>
# <br /> <br /> <br /> <br /> <br />
# <br><b>Respuesta</b><br>
# 3
#
# <br><b>Explicación</b><br>
#
# ![image.png](attachment:image.png)
#
#
# <br><b>Prueba</b><br>
#
# 100<br>
# 50 49 38 49 78 36 25 96 10 67 78 58 98 8 53 1 4 7 29 6 59 93 74 3 67 47 12 85 84 40 81 85 89 70 33 66 6 9 13 67 75 42 24 73 49 28 25 5 86 53 10 44 45 35 47 11 81 10 47 16 49 79 52 89 100 36 6 57 96 18 23 71 11 99 95 12 78 19 16 64 23 77 7 19 11 5 81 43 14 27 11 63 57 62 3 56 50 9 13 45
# <br><b>Respuesta esperada</b><br>
# 28

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete la función 'sockMerchant'
#
# Se espera que la función devuelva un INTEGER.
# La función acepta los siguientes parametros:
#  1. INTEGER n
#  2. INTEGER_ARRAY ar
#

def buscaPares(n, ar):
    # Su código acá
    
n = int(input().strip())
ar = list(map(int, input().rstrip().split()))
result = buscaPares(n, ar)
print(result)
