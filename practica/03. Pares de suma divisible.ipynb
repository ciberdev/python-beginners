# %% [markdown]
# Dada una matriz de enteros y un entero positivo k, determinar el número de (i,j) pares donde y ar[i] + ar[j] es divisible por k.
#
# <b>Ejemplo</b>
#
# ar = [1,2,3,4,5,6] <br>
# k = 5
#
# Tres pares cumplen los criterios: [1,4], [2,3] y [4,6].
#
# <b>Función descriptiva</b>
#
# Complete la función sumaDeParesDivisibles en el editor a continuación.
#
# sumaDeParesDivisibles tiene los siguientes parámetros:
#
# <ul>
# <li>int n: la longitud de la lista</li>
# <li>int ar[n]: una lista de enteros</li>
# <li>int k: el divisor entero</li>
# </ul>
#
# <b>Devuelve</b><br>
#
# <ul>
#     <li>int: el número de pares</li>
# </ul>
#
# <b>Formato de entrada</b><br>
#
# La primera línea contiene 2 enteros separados por espacios, n y k.<br>
# La segunda línea contiene n enteros separados por espacios, cada uno con un valor de arr[i].<br>
#
# <b>Restricciones</b><br>
# 2<=n<=100<br>
# 1<=k<=100<br>
# 1<=ar[i]<=100
#
# <b>Ejemplo</b><br>
#
# <table width="300" style="float:left">
#     <tr>
#         <td width="50%">STDIN</td><td>Function</td>
#    </tr>
#    <tr>
#         <td>-----</td><td>--------</td>
#
#    </tr>
#    <tr>
#         <td>6 3</td><td>n = 6, k = 3</td>
#
#    </tr>
#    <tr>
#         <td>1 3 2 6 1 2</td><td>ar = [1, 3, 2, 6, 1, 2]</td>
#    <tr>
# <table>
#
# <br /> <br /> <br /> <br /> <br />
# <b>Respuesta</b><br>
#
# 5
#
#
# <b>Caso de Prueba:</b><br>
# 100 32<br>
# 99 40 53 31 92 68 17 70 100 16 26 82 72 89 19 14 56 7 26 69 8 44 51 88 24 34 40 70 90 68 95 95 28 39 71 75 31 17 96 60 98 98 33 35 68 84 17 11 76 17 45 61 72 76 18 67 55 81 57 43 45 96 58 49 4 61 38 66 82 16 44 100 50 19 82 15 72 5 81 97 94 70 7 92 75 55 1 87 4 9 92 35 83 20 53 8 90 2 92 82
# <br><b>Respuesta:</b><br>
# 158

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete la función 'divisibleSumPairs'.
#
# Se espera que esta función devuelva un INTEGER.
# La función acepta los siguientes parametros:
#  1. INTEGER n  longitud de la lista (arreglo)
#  2. INTEGER k  divisor
#  3. INTEGER_ARRAY ar lista
#

def sumaDeParesDivisibles(n, k, ar):
    # su código acá
    
first_multiple_input = input().rstrip().split()
n = int(first_multiple_input[0])
k = int(first_multiple_input[1])
ar = list(map(int, input().rstrip().split()))
result = sumaDeParesDivisibles(n, k, ar)

print(result)
